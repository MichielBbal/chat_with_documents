# %% [markdown]
# # Langchain multiple PDF's
#
# Medium: https://medium.com/@brianlimyisheng1997/tutorial-how-to-get-gpt-to-read-from-pdfs-cccc4d189a2b

# %%
_ = !pip install openai
_ = !pip install langchain 
_ = !pip install Cython
_ = !pip install chromadb
_ = !pip install unstructured "unstructured[local-inference]"
_ = !CC=clang CXX=clang++ ARCHFLAGS="-arch x86_64" pip install 'git+https://github.com/facebookresearch/detectron2.git'
_ = !apt-get install poppler-utils
# Out:
# ^C

# %%
pip install "detectron2@git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2"
# Out:
# Collecting detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2
#   Cloning https://github.com/facebookresearch/detectron2.git (to revision e2ce8dc) to /private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-vhdoqs9p/detectron2_51756bd415634474aa8adb7067194fe3
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-vhdoqs9p/detectron2_51756bd415634474aa8adb7067194fe3
#   WARNING: Did not find branch or tag 'e2ce8dc', assuming revision or ref.
#   Running command git checkout -q e2ce8dc
#   Resolved https://github.com/facebookresearch/detectron2.git to commit e2ce8dc
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (9.4.0)
# Requirement already satisfied: matplotlib in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (3.7.0)
# Collecting pycocotools>=2.0.2
#   Using cached pycocotools-2.0.6.tar.gz (24 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: termcolor>=1.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (2.2.0)
# Collecting yacs>=0.1.8
#   Using cached yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (0.8.10)
# Requirement already satisfied: cloudpickle in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (2.0.0)
# Requirement already satisfied: tqdm>4.29.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (4.61.2)
# Collecting tensorboard
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 14.7 MB/s eta 0:00:0000:0100:01
# Collecting fvcore<0.1.6,>=0.1.5
#   Using cached fvcore-0.1.5.post20221221-py3-none-any.whl
# Collecting iopath<0.1.10,>=0.1.7
#   Using cached iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf>=2.1
#   Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Collecting hydra-core>=1.1
#   Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Requirement already satisfied: black in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (22.6.0)
# Requirement already satisfied: packaging in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (22.0)
# Requirement already satisfied: numpy in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (1.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (6.0)
# Collecting antlr4-python3-runtime==4.9.*
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Collecting portalocker
#   Using cached portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (3.0.9)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (0.4.3)
# Requirement already satisfied: tomli>=1.1.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (2.0.1)
# Requirement already satisfied: platformdirs>=2 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (2.5.2)
# Requirement already satisfied: click>=8.0.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (8.0.4)
# Requirement already satisfied: pathspec>=0.9.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (0.10.3)
# Collecting absl-py>=0.4
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Requirement already satisfied: protobuf>=3.19.6 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (4.22.1)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (0.7.0)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (65.6.3)
# Requirement already satisfied: wheel>=0.26 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (0.38.4)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (2.2.2)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.17.3-py2.py3-none-any.whl (178 kB)
# Collecting grpcio>=1.48.2
#   Using cached grpcio-1.54.0.tar.gz (23.5 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (2.25.1)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (4.9)
# Requirement already satisfied: six>=1.9.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (0.2.8)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: idna<3,>=2.5 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (1.26.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@e2ce8dc#egg=detectron2) (3.2.2)
# Building wheels for collected packages: detectron2, pycocotools, grpcio
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp310-cp310-macosx_10_9_x86_64.whl size=869790 sha256=a7b48b20061ccf048937434fb1219eaa0665389ad5e4b1e19e4a1a196503ae8a
#   Stored in directory: /private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-ephem-wheel-cache-croz4o0x/wheels/53/ab/d7/fe58ff2ddf8359c3fcaaf04b505a52800ef25e750a6e68a074
#   Building wheel for pycocotools (pyproject.toml) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0.6-cp310-cp310-macosx_10_9_x86_64.whl size=87341 sha256=e84af190e3cdbce65403da08fa21862dded34a035d2b5c442782314174bc658b
#   Stored in directory: /Users/michielbontenbal/Library/Caches/pip/wheels/89/5c/59/e3cd7600cf164a071163f9fed6550a29185d64345591f7d9fe
#   Building wheel for grpcio (setup.py) ... done
#   Created wheel for grpcio: filename=grpcio-1.54.0-cp310-cp310-macosx_10_10_x86_64.whl size=4086345 sha256=b7cbcfa39fdfad9a19b85fe299e79472fee15e72cb6d324f3f1ddb1a4e6ee44b
#   Stored in directory: /Users/michielbontenbal/Library/Caches/pip/wheels/27/0e/61/4cf20f71556bec2d5e14bf92ea439258db248b59656b9d8317
# Successfully built detectron2 pycocotools grpcio
# Installing collected packages: antlr4-python3-runtime, yacs, portalocker, omegaconf, grpcio, cachetools, absl-py, requests-oauthlib, iopath, hydra-core, google-auth, pycocotools, google-auth-oauthlib, fvcore, tensorboard, detectron2
# Successfully installed absl-py-1.4.0 antlr4-python3-runtime-4.9.3 cachetools-5.3.0 detectron2-0.6 fvcore-0.1.5.post20221221 google-auth-2.17.3 google-auth-oauthlib-1.0.0 grpcio-1.54.0 hydra-core-1.3.2 iopath-0.1.9 omegaconf-2.3.0 portalocker-2.7.0 pycocotools-2.0.6 requests-oauthlib-1.3.1 tensorboard-2.13.0 yacs-0.1.8
# Note: you may need to restart the kernel to use updated packages.

# %%
# !CC=clang CXX=clang++ ARCHFLAGS="-arch x86_64" python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-req-build-yonjj0hr
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-req-build-yonjj0hr
#   Resolved https://github.com/facebookresearch/detectron2.git to commit ebb26b5b0d914a9fc196da303e536892165a7113
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (9.4.0)
# Requirement already satisfied: matplotlib in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (3.7.0)
# Collecting pycocotools>=2.0.2
#   Using cached pycocotools-2.0.6.tar.gz (24 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: termcolor>=1.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (2.2.0)
# Collecting yacs>=0.1.8
#   Using cached yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (0.8.10)
# Requirement already satisfied: cloudpickle in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (2.0.0)
# Requirement already satisfied: tqdm>4.29.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (4.64.1)
# Collecting tensorboard
#   Using cached tensorboard-2.12.2-py3-none-any.whl (5.6 MB)
# Collecting fvcore<0.1.6,>=0.1.5
#   Using cached fvcore-0.1.5.post20221221-py3-none-any.whl
# Collecting iopath<0.1.10,>=0.1.7
#   Using cached iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf>=2.1
#   Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Collecting hydra-core>=1.1
#   Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Requirement already satisfied: black in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (22.6.0)
# Requirement already satisfied: packaging in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (22.0)
# Requirement already satisfied: numpy in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0)
# Collecting antlr4-python3-runtime==4.9.*
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Collecting portalocker
#   Using cached portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (3.0.9)
# Requirement already satisfied: click>=8.0.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2==0.6) (8.0.4)
# Requirement already satisfied: pathspec>=0.9.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2==0.6) (0.10.3)
# Requirement already satisfied: tomli>=1.1.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2==0.6) (0.4.3)
# Requirement already satisfied: platformdirs>=2 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2==0.6) (2.5.2)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.17.3-py2.py3-none-any.whl (178 kB)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (1.8.1)
# Collecting grpcio>=1.48.2
#   Using cached grpcio-1.54.0.tar.gz (23.5 MB)
#   Preparing metadata (setup.py) ... done
# Collecting absl-py>=0.4
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Requirement already satisfied: markdown>=2.6.8 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (3.4.1)
# Requirement already satisfied: protobuf>=3.19.6 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (4.22.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (2.2.2)
# Requirement already satisfied: wheel>=0.26 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (0.38.4)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (65.6.3)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (2.28.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: six>=1.9.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (1.16.0)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.2.8)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Building wheels for collected packages: detectron2, pycocotools, grpcio
#   Building wheel for detectron2 (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [471 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-10.9-x86_64-cpython-310
#       creating build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/lightning_train_net.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/convert-torchvision-to-d2.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/benchmark.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/visualize_data.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/plain_train_net.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/visualize_json_results.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/analyze_model.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/lazyconfig_train_net.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/train_net.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2
#       copying detectron2/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/checkpoint
#       copying detectron2/checkpoint/catalog.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/checkpoint
#       copying detectron2/checkpoint/c2_model_loading.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/checkpoint
#       copying detectron2/checkpoint/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/checkpoint
#       copying detectron2/checkpoint/detection_checkpoint.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/checkpoint
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/deform_conv.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/shape_spec.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/roi_align.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/roi_align_rotated.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/nms.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/aspp.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/mask_ops.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/wrappers.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/losses.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/blocks.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/batch_norm.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/rotated_boxes.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/instances.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/boxes.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/keypoints.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/masks.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/image_list.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/rotated_boxes.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       copying detectron2/config/config.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       copying detectron2/config/compat.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       copying detectron2/config/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       copying detectron2/config/instantiate.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       copying detectron2/config/defaults.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       copying detectron2/config/lazy.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects
#       copying detectron2/projects/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/serialize.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/colormap.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/tracing.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/env.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/analysis.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/comm.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/memory.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/video_visualizer.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/registry.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/events.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/collect_env.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/logger.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/file_io.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/develop.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/testing.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/visualizer.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/solver
#       copying detectron2/solver/build.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/solver
#       copying detectron2/solver/lr_scheduler.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/solver
#       copying detectron2/solver/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/solver
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo
#       copying detectron2/model_zoo/model_zoo.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo
#       copying detectron2/model_zoo/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/test_time_augmentation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/poolers.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/matcher.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/box_regression.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/mmdet_wrapper.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/anchor_generator.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/sampling.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/postprocessing.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/fast_eval_api.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/panoptic_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/cityscapes_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/coco_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/sem_seg_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/pascal_voc_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/lvis_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/testing.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/evaluator.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/rotated_coco_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/bbox_iou_tracker.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/vanilla_hungarian_bbox_iou_tracker.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/hungarian_tracker.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/base_tracker.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/utils.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/iou_weighted_hungarian_bbox_iou_tracker.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/c10.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/caffe2_export.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/flatten.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/caffe2_patch.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/caffe2_modeling.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/shared.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/api.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/caffe2_inference.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/torchscript_patch.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/torchscript.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/catalog.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/build.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/benchmark.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/detection_utils.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/dataset_mapper.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/common.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/engine
#       copying detectron2/engine/hooks.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/engine
#       copying detectron2/engine/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/engine
#       copying detectron2/engine/train_loop.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/engine
#       copying detectron2/engine/launch.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/engine
#       copying detectron2/engine/defaults.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/engine
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/build.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/rcnn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/panoptic_fpn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/dense_detector.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/fcos.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/retinanet.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/semantic_seg.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/proposal_generator
#       copying detectron2/modeling/proposal_generator/build.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/proposal_generator
#       copying detectron2/modeling/proposal_generator/rpn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/proposal_generator
#       copying detectron2/modeling/proposal_generator/rrpn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/proposal_generator
#       copying detectron2/modeling/proposal_generator/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/proposal_generator
#       copying detectron2/modeling/proposal_generator/proposal_utils.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/proposal_generator
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/mask_head.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/fast_rcnn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/box_head.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/keypoint_head.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/rotated_fast_rcnn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/cascade_rcnn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/roi_heads.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/build.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/fpn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/regnet.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/swin.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/backbone.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/vit.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/resnet.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/utils.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/mvit.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/coco.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/register_coco.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/cityscapes.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/cityscapes_panoptic.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/lvis_v1_categories.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/lvis.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/coco_panoptic.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/builtin.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/lvis_v1_category_image_count.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/pascal_voc.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/lvis_v0_5_categories.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/builtin_meta.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/transforms
#       copying detectron2/data/transforms/augmentation_impl.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/transforms
#       copying detectron2/data/transforms/augmentation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/transforms
#       copying detectron2/data/transforms/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/transforms
#       copying detectron2/data/transforms/transform.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/transforms
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/samplers
#       copying detectron2/data/samplers/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/samplers
#       copying detectron2/data/samplers/grouped_batch_sampler.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/samplers
#       copying detectron2/data/samplers/distributed_sampler.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/samplers
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/point_features.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/mask_head.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/config.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/point_head.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/roi_heads.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/color_augmentation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/semantic_seg.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/lr_scheduler.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/config.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/loss.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/resnet.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/build_solver.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/semantic_seg.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       copying projects/Panoptic-DeepLab/panoptic_deeplab/config.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       copying projects/Panoptic-DeepLab/panoptic_deeplab/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       copying projects/Panoptic-DeepLab/panoptic_deeplab/dataset_mapper.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       copying projects/Panoptic-DeepLab/panoptic_deeplab/panoptic_seg.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       copying projects/Panoptic-DeepLab/panoptic_deeplab/post_processing.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       copying projects/Panoptic-DeepLab/panoptic_deeplab/target_generator.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs
#       copying detectron2/model_zoo/configs/Base-RetinaNet.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs
#       copying detectron2/model_zoo/configs/Base-RCNN-FPN.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs
#       copying detectron2/model_zoo/configs/Base-RCNN-C4.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs
#       copying detectron2/model_zoo/configs/Base-RCNN-DilatedC5.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/scratch_mask_rcnn_R_50_FPN_9x_syncbn.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/mask_rcnn_R_50_FPN_3x_dconv_c3-c5.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/semantic_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/scratch_mask_rcnn_R_50_FPN_3x_gn.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/panoptic_fpn_R_101_dconv_cascade_gn_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/scratch_mask_rcnn_R_50_FPN_9x_gn.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/mask_rcnn_R_50_FPN_3x_gn.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/mask_rcnn_R_50_FPN_1x_dconv_c3-c5.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/cascade_mask_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/cascade_mask_rcnn_X_152_32x8d_FPN_IN5k_gn_dconv.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/mask_rcnn_R_50_FPN_1x_cls_agnostic.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/cascade_mask_rcnn_R_50_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/mask_rcnn_R_50_FPN_3x_syncbn.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Keypoints
#       copying detectron2/model_zoo/configs/COCO-Keypoints/keypoint_rcnn_X_101_32x8d_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Keypoints
#       copying detectron2/model_zoo/configs/COCO-Keypoints/keypoint_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Keypoints
#       copying detectron2/model_zoo/configs/COCO-Keypoints/keypoint_rcnn_R_50_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Keypoints
#       copying detectron2/model_zoo/configs/COCO-Keypoints/Base-Keypoint-RCNN-FPN.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Keypoints
#       copying detectron2/model_zoo/configs/COCO-Keypoints/keypoint_rcnn_R_101_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Keypoints
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/PascalVOC-Detection
#       copying detectron2/model_zoo/configs/PascalVOC-Detection/faster_rcnn_R_50_FPN.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/PascalVOC-Detection
#       copying detectron2/model_zoo/configs/PascalVOC-Detection/faster_rcnn_R_50_C4.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/PascalVOC-Detection
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Detectron1-Comparisons
#       copying detectron2/model_zoo/configs/Detectron1-Comparisons/mask_rcnn_R_50_FPN_noaug_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Detectron1-Comparisons
#       copying detectron2/model_zoo/configs/Detectron1-Comparisons/keypoint_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Detectron1-Comparisons
#       copying detectron2/model_zoo/configs/Detectron1-Comparisons/faster_rcnn_R_50_FPN_noaug_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Detectron1-Comparisons
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/rpn_R_50_C4_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/rpn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_101_C4_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/retinanet_R_101_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_101_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_50_DC5_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_50_DC5_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_50_C4_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_50_C4_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/fast_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/retinanet_R_50_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_101_DC5_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/retinanet_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-PanopticSegmentation
#       copying detectron2/model_zoo/configs/COCO-PanopticSegmentation/panoptic_fpn_R_101_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-PanopticSegmentation
#       copying detectron2/model_zoo/configs/COCO-PanopticSegmentation/Base-Panoptic-FPN.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-PanopticSegmentation
#       copying detectron2/model_zoo/configs/COCO-PanopticSegmentation/panoptic_fpn_R_50_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-PanopticSegmentation
#       copying detectron2/model_zoo/configs/COCO-PanopticSegmentation/panoptic_fpn_R_50_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-PanopticSegmentation
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv1-InstanceSegmentation
#       copying detectron2/model_zoo/configs/LVISv1-InstanceSegmentation/mask_rcnn_R_101_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv1-InstanceSegmentation
#       copying detectron2/model_zoo/configs/LVISv1-InstanceSegmentation/mask_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv1-InstanceSegmentation
#       copying detectron2/model_zoo/configs/LVISv1-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv1-InstanceSegmentation
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation
#       copying detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation/mask_rcnn_R_101_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation
#       copying detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation/mask_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation
#       copying detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/keypoint_rcnn_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_FPN_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_C4_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/cascade_mask_rcnn_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_C4_GCV_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_C4_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_FPN_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/panoptic_fpn_R_50_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/retinanet_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_DC5_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/retinanet_R_50_FPN_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_FPN_pred_boxes_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/panoptic_fpn_R_50_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/rpn_R_50_FPN_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/semantic_R_50_FPN_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/keypoint_rcnn_R_50_FPN_normalized_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/panoptic_fpn_R_50_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/cascade_mask_rcnn_R_50_FPN_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/fast_rcnn_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/semantic_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/rpn_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/keypoint_rcnn_R_50_FPN_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/keypoint_rcnn_R_50_FPN_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_C4_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/semantic_R_50_FPN_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
# ...
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -arch x86_64 -D_WIN32_WINNT=1536 -DGRPC_XDS_USER_AGENT_NAME_SUFFIX=\"Python\" -DGRPC_XDS_USER_AGENT_VERSION_SUFFIX=\"1.54.0\" -DGPR_BACKWARDS_COMPATIBILITY_MODE=1 -DHAVE_CONFIG_H=1 -DGRPC_ENABLE_FORK_SUPPORT=1 "-DPyMODINIT_FUNC=extern \"C\" __attribute__((visibility (\"default\"))) PyObject*" -DGRPC_POSIX_FORK_ALLOW_PTHREAD_ATFORK=1 -Isrc/python/grpcio -Iinclude -I. -Ithird_party/abseil-cpp -Ithird_party/address_sorting/include -Ithird_party/cares/cares/include -Ithird_party/cares -Ithird_party/cares/cares -Ithird_party/cares/config_darwin -Ithird_party/re2 -Ithird_party/boringssl-with-bazel/src/include -Ithird_party/upb -Isrc/core/ext/upb-generated -Isrc/core/ext/upbdefs-generated -Ithird_party/xxhash -Ithird_party/zlib -I/Users/michielbontenbal/anaconda3/include/python3.10 -c third_party/cares/cares/src/lib/ares_getenv.c -o python_build/temp.macosx-10.10-x86_64-cpython-310/third_party/cares/cares/src/lib/ares_getenv.o -std=c++14 -stdlib=libc++ -fvisibility=hidden -fno-wrapv -fno-exceptions -DHAVE_UNISTD_H -pthread
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -arch x86_64 -D_WIN32_WINNT=1536 -DGRPC_XDS_USER_AGENT_NAME_SUFFIX=\"Python\" -DGRPC_XDS_USER_AGENT_VERSION_SUFFIX=\"1.54.0\" -DGPR_BACKWARDS_COMPATIBILITY_MODE=1 -DHAVE_CONFIG_H=1 -DGRPC_ENABLE_FORK_SUPPORT=1 "-DPyMODINIT_FUNC=extern \"C\" __attribute__((visibility (\"default\"))) PyObject*" -DGRPC_POSIX_FORK_ALLOW_PTHREAD_ATFORK=1 -Isrc/python/grpcio -Iinclude -I. -Ithird_party/abseil-cpp -Ithird_party/address_sorting/include -Ithird_party/cares/cares/include -Ithird_party/cares -Ithird_party/cares/cares -Ithird_party/cares/config_darwin -Ithird_party/re2 -Ithird_party/boringssl-with-bazel/src/include -Ithird_party/upb -Isrc/core/ext/upb-generated -Isrc/core/ext/upbdefs-generated -Ithird_party/xxhash -Ithird_party/zlib -I/Users/michielbontenbal/anaconda3/include/python3.10 -c third_party/re2/re2/nfa.cc -o python_build/temp.macosx-10.10-x86_64-cpython-310/third_party/re2/re2/nfa.o -std=c++14 -stdlib=libc++ -fvisibility=hidden -fno-wrapv -fno-exceptions -DHAVE_UNISTD_H -pthread
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -arch x86_64 -D_WIN32_WINNT=1536 -DGRPC_XDS_USER_AGENT_NAME_SUFFIX=\"Python\" -DGRPC_XDS_USER_AGENT_VERSION_SUFFIX=\"1.54.0\" -DGPR_BACKWARDS_COMPATIBILITY_MODE=1 -DHAVE_CONFIG_H=1 -DGRPC_ENABLE_FORK_SUPPORT=1 "-DPyMODINIT_FUNC=extern \"C\" __attribute__((visibility (\"default\"))) PyObject*" -DGRPC_POSIX_FORK_ALLOW_PTHREAD_ATFORK=1 -Isrc/python/grpcio -Iinclude -I. -Ithird_party/abseil-cpp -Ithird_party/address_sorting/include -Ithird_party/cares/cares/include -Ithird_party/cares -Ithird_party/cares/cares -Ithird_party/cares/config_darwin -Ithird_party/re2 -Ithird_party/boringssl-with-bazel/src/include -Ithird_party/upb -Isrc/core/ext/upb-generated -Isrc/core/ext/upbdefs-generated -Ithird_party/xxhash -Ithird_party/zlib -I/Users/michielbontenbal/anaconda3/include/python3.10 -c third_party/zlib/gzclose.c -o python_build/temp.macosx-10.10-x86_64-cpython-310/third_party/zlib/gzclose.o -std=c++14 -stdlib=libc++ -fvisibility=hidden -fno-wrapv -fno-exceptions -DHAVE_UNISTD_H -pthread
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       creating None
#       creating None/var
#       creating None/var/folders
#       creating None/var/folders/cj
#       creating None/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn
#       creating None/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T
#       creating None/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmpzo3ceb4l
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -arch x86_64 -I/Users/michielbontenbal/anaconda3/include/python3.10 -c /var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmpzo3ceb4l/a.c -o None/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmpzo3ceb4l/a.o
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#
#       Could not find <Python.h>. This could mean the following:
#         * You're on Ubuntu and haven't run `apt-get install python3-dev`.
#         * You're on RHEL/Fedora and haven't run `yum install python3-devel` or
#           `dnf install python3-devel` (make sure you also have redhat-rpm-config
#           installed)
#         * You're on Mac OS X and the usual Python framework was somehow corrupted
#           (check your environment variables or try re-installing?)
#         * You're on Windows and your Python installation was somehow corrupted
#           (check your environment variables or try re-installing?)
#       Traceback (most recent call last):
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/unixccompiler.py", line 186, in _compile
#           self.spawn(compiler_so + cc_args + [src, '-o', obj] + extra_postargs)
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-05cqed95/grpcio_98be799c588841c29063a394516ef1e9/src/python/grpcio/_spawn_patch.py", line 54, in _commandfile_spawn
#           _classic_spawn(self, command)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/ccompiler.py", line 1007, in spawn
#           spawn(cmd, dry_run=self.dry_run, **kwargs)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/spawn.py", line 70, in spawn
#           raise DistutilsExecError(
#       distutils.errors.DistutilsExecError: command '/usr/bin/clang' failed with exit code 1
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-05cqed95/grpcio_98be799c588841c29063a394516ef1e9/src/python/grpcio/commands.py", line 281, in build_extensions
#           build_ext.build_ext.build_extensions(self)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/Cython/Distutils/old_build_ext.py", line 195, in build_extensions
#           _build_ext.build_ext.build_extensions(self)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 468, in build_extensions
#           self._build_extensions_serial()
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 494, in _build_extensions_serial
#           self.build_extension(ext)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/command/build_ext.py", line 246, in build_extension
#           _build_ext.build_extension(self, ext)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 549, in build_extension
#           objects = self.compiler.compile(
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-05cqed95/grpcio_98be799c588841c29063a394516ef1e9/src/python/grpcio/_parallel_compile_patch.py", line 58, in _parallel_compile
#           multiprocessing.pool.ThreadPool(BUILD_EXT_COMPILER_JOBS).map(
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/multiprocessing/pool.py", line 367, in map
#           return self._map_async(func, iterable, mapstar, chunksize).get()
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/multiprocessing/pool.py", line 774, in get
#           raise self._value
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#           result = (True, func(*args, **kwds))
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#           return list(map(*args))
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-05cqed95/grpcio_98be799c588841c29063a394516ef1e9/src/python/grpcio/_parallel_compile_patch.py", line 54, in _compile_single_file
#           self._compile(obj, src, ext, cc_args, extra_postargs, pp_opts)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/unixccompiler.py", line 188, in _compile
#           raise CompileError(msg)
#       distutils.errors.CompileError: command '/usr/bin/clang' failed with exit code 1
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-05cqed95/grpcio_98be799c588841c29063a394516ef1e9/setup.py", line 537, in <module>
#           setuptools.setup(
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/__init__.py", line 87, in setup
#           return distutils.core.setup(**attrs)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/wheel/bdist_wheel.py", line 325, in run
#           self.run_command("build")
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/build.py", line 132, in run
#           self.run_command(cmd_name)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/command/build_ext.py", line 84, in run
#           _build_ext.run(self)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/Cython/Distutils/old_build_ext.py", line 186, in run
#           _build_ext.build_ext.run(self)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 346, in run
#           self.build_extensions()
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-05cqed95/grpcio_98be799c588841c29063a394516ef1e9/src/python/grpcio/commands.py", line 284, in build_extensions
#           support.diagnose_build_ext_error(self, error, formatted_exception)
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-05cqed95/grpcio_98be799c588841c29063a394516ef1e9/src/python/grpcio/support.py", line 117, in diagnose_build_ext_error
#           diagnostic(build_ext, error)
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-05cqed95/grpcio_98be799c588841c29063a394516ef1e9/src/python/grpcio/support.py", line 76, in diagnose_compile_error
#           _expect_compile(build_ext.compiler, c_check, message)
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-05cqed95/grpcio_98be799c588841c29063a394516ef1e9/src/python/grpcio/support.py", line 68, in _expect_compile
#           raise commands.CommandError(
#       commands.CommandError: Diagnostics found a compilation environment issue:
#
#       Could not find <Python.h>. This could mean the following:
#         * You're on Ubuntu and haven't run `apt-get install python3-dev`.
#         * You're on RHEL/Fedora and haven't run `yum install python3-devel` or
#           `dnf install python3-devel` (make sure you also have redhat-rpm-config
#           installed)
#         * You're on Mac OS X and the usual Python framework was somehow corrupted
#           (check your environment variables or try re-installing?)
#         * You're on Windows and your Python installation was somehow corrupted
#           (check your environment variables or try re-installing?)
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for grpcio
#   Running setup.py clean for grpcio
# Failed to build detectron2 pycocotools grpcio
# ERROR: Could not build wheels for pycocotools, which is required to install pyproject.toml-based projects

# %%
# !CC=clang CXX=clang++ ARCHFLAGS="-arch x86_64" pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-req-build-rlu5w4pe
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-req-build-rlu5w4pe
#   Resolved https://github.com/facebookresearch/detectron2.git to commit ebb26b5b0d914a9fc196da303e536892165a7113
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (9.4.0)
# Requirement already satisfied: matplotlib in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (3.7.0)
# Collecting pycocotools>=2.0.2
#   Using cached pycocotools-2.0.6.tar.gz (24 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: termcolor>=1.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (2.2.0)
# Collecting yacs>=0.1.8
#   Using cached yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (0.8.10)
# Requirement already satisfied: cloudpickle in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (2.0.0)
# Requirement already satisfied: tqdm>4.29.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (4.64.1)
# Collecting tensorboard
#   Using cached tensorboard-2.12.2-py3-none-any.whl (5.6 MB)
# Collecting fvcore<0.1.6,>=0.1.5
#   Using cached fvcore-0.1.5.post20221221.tar.gz (50 kB)
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7
#   Using cached iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf>=2.1
#   Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Collecting hydra-core>=1.1
#   Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Requirement already satisfied: black in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (22.6.0)
# Requirement already satisfied: packaging in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (22.0)
# Requirement already satisfied: numpy in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0)
# Collecting antlr4-python3-runtime==4.9.*
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Collecting portalocker
#   Using cached portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: cycler>=0.10 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (4.25.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2==0.6) (0.4.3)
# Requirement already satisfied: platformdirs>=2 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2==0.6) (2.5.2)
# Requirement already satisfied: tomli>=1.1.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: click>=8.0.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2==0.6) (8.0.4)
# Requirement already satisfied: pathspec>=0.9.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2==0.6) (0.10.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (1.8.1)
# Collecting grpcio>=1.48.2
#   Using cached grpcio-1.54.0.tar.gz (23.5 MB)
#   Preparing metadata (setup.py) ... done
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting absl-py>=0.4
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Requirement already satisfied: wheel>=0.26 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (0.38.4)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (65.6.3)
# Requirement already satisfied: protobuf>=3.19.6 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (4.22.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (2.28.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (2.2.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (0.7.0)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.17.3-py2.py3-none-any.whl (178 kB)
# Requirement already satisfied: markdown>=2.6.8 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (3.4.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.2.8)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: six>=1.9.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (1.26.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Building wheels for collected packages: detectron2, fvcore, pycocotools, grpcio
#   Building wheel for detectron2 (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [471 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-10.9-x86_64-cpython-310
#       creating build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/lightning_train_net.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/convert-torchvision-to-d2.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/benchmark.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/visualize_data.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/plain_train_net.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/visualize_json_results.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/analyze_model.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/lazyconfig_train_net.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/train_net.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2
#       copying detectron2/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/checkpoint
#       copying detectron2/checkpoint/catalog.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/checkpoint
#       copying detectron2/checkpoint/c2_model_loading.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/checkpoint
#       copying detectron2/checkpoint/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/checkpoint
#       copying detectron2/checkpoint/detection_checkpoint.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/checkpoint
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/deform_conv.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/shape_spec.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/roi_align.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/roi_align_rotated.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/nms.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/aspp.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/mask_ops.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/wrappers.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/losses.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/blocks.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/batch_norm.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/rotated_boxes.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/instances.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/boxes.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/keypoints.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/masks.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/image_list.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/rotated_boxes.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       copying detectron2/config/config.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       copying detectron2/config/compat.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       copying detectron2/config/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       copying detectron2/config/instantiate.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       copying detectron2/config/defaults.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       copying detectron2/config/lazy.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects
#       copying detectron2/projects/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/serialize.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/colormap.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/tracing.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/env.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/analysis.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/comm.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/memory.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/video_visualizer.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/registry.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/events.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/collect_env.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/logger.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/file_io.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/develop.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/testing.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/visualizer.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/solver
#       copying detectron2/solver/build.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/solver
#       copying detectron2/solver/lr_scheduler.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/solver
#       copying detectron2/solver/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/solver
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo
#       copying detectron2/model_zoo/model_zoo.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo
#       copying detectron2/model_zoo/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/test_time_augmentation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/poolers.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/matcher.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/box_regression.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/mmdet_wrapper.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/anchor_generator.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/sampling.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/postprocessing.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/fast_eval_api.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/panoptic_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/cityscapes_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/coco_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/sem_seg_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/pascal_voc_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/lvis_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/testing.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/evaluator.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/rotated_coco_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/bbox_iou_tracker.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/vanilla_hungarian_bbox_iou_tracker.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/hungarian_tracker.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/base_tracker.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/utils.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/iou_weighted_hungarian_bbox_iou_tracker.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/c10.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/caffe2_export.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/flatten.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/caffe2_patch.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/caffe2_modeling.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/shared.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/api.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/caffe2_inference.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/torchscript_patch.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/torchscript.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/catalog.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/build.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/benchmark.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/detection_utils.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/dataset_mapper.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/common.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/engine
#       copying detectron2/engine/hooks.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/engine
#       copying detectron2/engine/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/engine
#       copying detectron2/engine/train_loop.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/engine
#       copying detectron2/engine/launch.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/engine
#       copying detectron2/engine/defaults.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/engine
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/build.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/rcnn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/panoptic_fpn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/dense_detector.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/fcos.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/retinanet.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/semantic_seg.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/proposal_generator
#       copying detectron2/modeling/proposal_generator/build.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/proposal_generator
#       copying detectron2/modeling/proposal_generator/rpn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/proposal_generator
#       copying detectron2/modeling/proposal_generator/rrpn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/proposal_generator
#       copying detectron2/modeling/proposal_generator/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/proposal_generator
#       copying detectron2/modeling/proposal_generator/proposal_utils.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/proposal_generator
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/mask_head.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/fast_rcnn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/box_head.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/keypoint_head.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/rotated_fast_rcnn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/cascade_rcnn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/roi_heads.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/build.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/fpn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/regnet.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/swin.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/backbone.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/vit.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/resnet.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/utils.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/mvit.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/coco.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/register_coco.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/cityscapes.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/cityscapes_panoptic.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/lvis_v1_categories.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/lvis.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/coco_panoptic.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/builtin.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/lvis_v1_category_image_count.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/pascal_voc.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/lvis_v0_5_categories.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/builtin_meta.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/transforms
#       copying detectron2/data/transforms/augmentation_impl.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/transforms
#       copying detectron2/data/transforms/augmentation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/transforms
#       copying detectron2/data/transforms/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/transforms
#       copying detectron2/data/transforms/transform.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/transforms
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/samplers
#       copying detectron2/data/samplers/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/samplers
#       copying detectron2/data/samplers/grouped_batch_sampler.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/samplers
#       copying detectron2/data/samplers/distributed_sampler.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/samplers
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/point_features.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/mask_head.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/config.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/point_head.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/roi_heads.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/color_augmentation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/semantic_seg.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/lr_scheduler.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/config.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/loss.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/resnet.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/build_solver.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/semantic_seg.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       copying projects/Panoptic-DeepLab/panoptic_deeplab/config.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       copying projects/Panoptic-DeepLab/panoptic_deeplab/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       copying projects/Panoptic-DeepLab/panoptic_deeplab/dataset_mapper.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       copying projects/Panoptic-DeepLab/panoptic_deeplab/panoptic_seg.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       copying projects/Panoptic-DeepLab/panoptic_deeplab/post_processing.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       copying projects/Panoptic-DeepLab/panoptic_deeplab/target_generator.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs
#       copying detectron2/model_zoo/configs/Base-RetinaNet.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs
#       copying detectron2/model_zoo/configs/Base-RCNN-FPN.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs
#       copying detectron2/model_zoo/configs/Base-RCNN-C4.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs
#       copying detectron2/model_zoo/configs/Base-RCNN-DilatedC5.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/scratch_mask_rcnn_R_50_FPN_9x_syncbn.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/mask_rcnn_R_50_FPN_3x_dconv_c3-c5.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/semantic_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/scratch_mask_rcnn_R_50_FPN_3x_gn.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/panoptic_fpn_R_101_dconv_cascade_gn_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/scratch_mask_rcnn_R_50_FPN_9x_gn.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/mask_rcnn_R_50_FPN_3x_gn.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/mask_rcnn_R_50_FPN_1x_dconv_c3-c5.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/cascade_mask_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/cascade_mask_rcnn_X_152_32x8d_FPN_IN5k_gn_dconv.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/mask_rcnn_R_50_FPN_1x_cls_agnostic.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/cascade_mask_rcnn_R_50_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/mask_rcnn_R_50_FPN_3x_syncbn.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Keypoints
#       copying detectron2/model_zoo/configs/COCO-Keypoints/keypoint_rcnn_X_101_32x8d_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Keypoints
#       copying detectron2/model_zoo/configs/COCO-Keypoints/keypoint_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Keypoints
#       copying detectron2/model_zoo/configs/COCO-Keypoints/keypoint_rcnn_R_50_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Keypoints
#       copying detectron2/model_zoo/configs/COCO-Keypoints/Base-Keypoint-RCNN-FPN.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Keypoints
#       copying detectron2/model_zoo/configs/COCO-Keypoints/keypoint_rcnn_R_101_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Keypoints
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/PascalVOC-Detection
#       copying detectron2/model_zoo/configs/PascalVOC-Detection/faster_rcnn_R_50_FPN.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/PascalVOC-Detection
#       copying detectron2/model_zoo/configs/PascalVOC-Detection/faster_rcnn_R_50_C4.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/PascalVOC-Detection
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Detectron1-Comparisons
#       copying detectron2/model_zoo/configs/Detectron1-Comparisons/mask_rcnn_R_50_FPN_noaug_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Detectron1-Comparisons
#       copying detectron2/model_zoo/configs/Detectron1-Comparisons/keypoint_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Detectron1-Comparisons
#       copying detectron2/model_zoo/configs/Detectron1-Comparisons/faster_rcnn_R_50_FPN_noaug_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Detectron1-Comparisons
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/rpn_R_50_C4_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/rpn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_101_C4_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/retinanet_R_101_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_101_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_50_DC5_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_50_DC5_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_50_C4_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_50_C4_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/fast_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/retinanet_R_50_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_101_DC5_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/retinanet_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-PanopticSegmentation
#       copying detectron2/model_zoo/configs/COCO-PanopticSegmentation/panoptic_fpn_R_101_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-PanopticSegmentation
#       copying detectron2/model_zoo/configs/COCO-PanopticSegmentation/Base-Panoptic-FPN.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-PanopticSegmentation
#       copying detectron2/model_zoo/configs/COCO-PanopticSegmentation/panoptic_fpn_R_50_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-PanopticSegmentation
#       copying detectron2/model_zoo/configs/COCO-PanopticSegmentation/panoptic_fpn_R_50_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-PanopticSegmentation
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv1-InstanceSegmentation
#       copying detectron2/model_zoo/configs/LVISv1-InstanceSegmentation/mask_rcnn_R_101_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv1-InstanceSegmentation
#       copying detectron2/model_zoo/configs/LVISv1-InstanceSegmentation/mask_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv1-InstanceSegmentation
#       copying detectron2/model_zoo/configs/LVISv1-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv1-InstanceSegmentation
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation
#       copying detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation/mask_rcnn_R_101_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation
#       copying detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation/mask_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation
#       copying detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/keypoint_rcnn_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_FPN_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_C4_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/cascade_mask_rcnn_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_C4_GCV_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_C4_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_FPN_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/panoptic_fpn_R_50_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/retinanet_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_DC5_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/retinanet_R_50_FPN_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_FPN_pred_boxes_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/panoptic_fpn_R_50_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/rpn_R_50_FPN_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/semantic_R_50_FPN_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/keypoint_rcnn_R_50_FPN_normalized_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/panoptic_fpn_R_50_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/cascade_mask_rcnn_R_50_FPN_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/fast_rcnn_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/semantic_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/rpn_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/keypoint_rcnn_R_50_FPN_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/keypoint_rcnn_R_50_FPN_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_C4_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/semantic_R_50_FPN_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
# ...
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -arch x86_64 -D_WIN32_WINNT=1536 -DGRPC_XDS_USER_AGENT_NAME_SUFFIX=\"Python\" -DGRPC_XDS_USER_AGENT_VERSION_SUFFIX=\"1.54.0\" -DGPR_BACKWARDS_COMPATIBILITY_MODE=1 -DHAVE_CONFIG_H=1 -DGRPC_ENABLE_FORK_SUPPORT=1 "-DPyMODINIT_FUNC=extern \"C\" __attribute__((visibility (\"default\"))) PyObject*" -DGRPC_POSIX_FORK_ALLOW_PTHREAD_ATFORK=1 -Isrc/python/grpcio -Iinclude -I. -Ithird_party/abseil-cpp -Ithird_party/address_sorting/include -Ithird_party/cares/cares/include -Ithird_party/cares -Ithird_party/cares/cares -Ithird_party/cares/config_darwin -Ithird_party/re2 -Ithird_party/boringssl-with-bazel/src/include -Ithird_party/upb -Isrc/core/ext/upb-generated -Isrc/core/ext/upbdefs-generated -Ithird_party/xxhash -Ithird_party/zlib -I/Users/michielbontenbal/anaconda3/include/python3.10 -c third_party/cares/cares/src/lib/ares_getenv.c -o python_build/temp.macosx-10.10-x86_64-cpython-310/third_party/cares/cares/src/lib/ares_getenv.o -std=c++14 -stdlib=libc++ -fvisibility=hidden -fno-wrapv -fno-exceptions -DHAVE_UNISTD_H -pthread
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -arch x86_64 -D_WIN32_WINNT=1536 -DGRPC_XDS_USER_AGENT_NAME_SUFFIX=\"Python\" -DGRPC_XDS_USER_AGENT_VERSION_SUFFIX=\"1.54.0\" -DGPR_BACKWARDS_COMPATIBILITY_MODE=1 -DHAVE_CONFIG_H=1 -DGRPC_ENABLE_FORK_SUPPORT=1 "-DPyMODINIT_FUNC=extern \"C\" __attribute__((visibility (\"default\"))) PyObject*" -DGRPC_POSIX_FORK_ALLOW_PTHREAD_ATFORK=1 -Isrc/python/grpcio -Iinclude -I. -Ithird_party/abseil-cpp -Ithird_party/address_sorting/include -Ithird_party/cares/cares/include -Ithird_party/cares -Ithird_party/cares/cares -Ithird_party/cares/config_darwin -Ithird_party/re2 -Ithird_party/boringssl-with-bazel/src/include -Ithird_party/upb -Isrc/core/ext/upb-generated -Isrc/core/ext/upbdefs-generated -Ithird_party/xxhash -Ithird_party/zlib -I/Users/michielbontenbal/anaconda3/include/python3.10 -c third_party/re2/re2/nfa.cc -o python_build/temp.macosx-10.10-x86_64-cpython-310/third_party/re2/re2/nfa.o -std=c++14 -stdlib=libc++ -fvisibility=hidden -fno-wrapv -fno-exceptions -DHAVE_UNISTD_H -pthread
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -arch x86_64 -D_WIN32_WINNT=1536 -DGRPC_XDS_USER_AGENT_NAME_SUFFIX=\"Python\" -DGRPC_XDS_USER_AGENT_VERSION_SUFFIX=\"1.54.0\" -DGPR_BACKWARDS_COMPATIBILITY_MODE=1 -DHAVE_CONFIG_H=1 -DGRPC_ENABLE_FORK_SUPPORT=1 "-DPyMODINIT_FUNC=extern \"C\" __attribute__((visibility (\"default\"))) PyObject*" -DGRPC_POSIX_FORK_ALLOW_PTHREAD_ATFORK=1 -Isrc/python/grpcio -Iinclude -I. -Ithird_party/abseil-cpp -Ithird_party/address_sorting/include -Ithird_party/cares/cares/include -Ithird_party/cares -Ithird_party/cares/cares -Ithird_party/cares/config_darwin -Ithird_party/re2 -Ithird_party/boringssl-with-bazel/src/include -Ithird_party/upb -Isrc/core/ext/upb-generated -Isrc/core/ext/upbdefs-generated -Ithird_party/xxhash -Ithird_party/zlib -I/Users/michielbontenbal/anaconda3/include/python3.10 -c third_party/zlib/gzclose.c -o python_build/temp.macosx-10.10-x86_64-cpython-310/third_party/zlib/gzclose.o -std=c++14 -stdlib=libc++ -fvisibility=hidden -fno-wrapv -fno-exceptions -DHAVE_UNISTD_H -pthread
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       creating None
#       creating None/var
#       creating None/var/folders
#       creating None/var/folders/cj
#       creating None/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn
#       creating None/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T
#       creating None/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmprr6j_2nr
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -arch x86_64 -I/Users/michielbontenbal/anaconda3/include/python3.10 -c /var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmprr6j_2nr/a.c -o None/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmprr6j_2nr/a.o
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#
#       Could not find <Python.h>. This could mean the following:
#         * You're on Ubuntu and haven't run `apt-get install python3-dev`.
#         * You're on RHEL/Fedora and haven't run `yum install python3-devel` or
#           `dnf install python3-devel` (make sure you also have redhat-rpm-config
#           installed)
#         * You're on Mac OS X and the usual Python framework was somehow corrupted
#           (check your environment variables or try re-installing?)
#         * You're on Windows and your Python installation was somehow corrupted
#           (check your environment variables or try re-installing?)
#       Traceback (most recent call last):
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/unixccompiler.py", line 186, in _compile
#           self.spawn(compiler_so + cc_args + [src, '-o', obj] + extra_postargs)
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-76iwm6xe/grpcio_8a4265f8188c43858205a7563dfbd1bc/src/python/grpcio/_spawn_patch.py", line 54, in _commandfile_spawn
#           _classic_spawn(self, command)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/ccompiler.py", line 1007, in spawn
#           spawn(cmd, dry_run=self.dry_run, **kwargs)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/spawn.py", line 70, in spawn
#           raise DistutilsExecError(
#       distutils.errors.DistutilsExecError: command '/usr/bin/clang' failed with exit code 1
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-76iwm6xe/grpcio_8a4265f8188c43858205a7563dfbd1bc/src/python/grpcio/commands.py", line 281, in build_extensions
#           build_ext.build_ext.build_extensions(self)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/Cython/Distutils/old_build_ext.py", line 195, in build_extensions
#           _build_ext.build_ext.build_extensions(self)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 468, in build_extensions
#           self._build_extensions_serial()
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 494, in _build_extensions_serial
#           self.build_extension(ext)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/command/build_ext.py", line 246, in build_extension
#           _build_ext.build_extension(self, ext)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 549, in build_extension
#           objects = self.compiler.compile(
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-76iwm6xe/grpcio_8a4265f8188c43858205a7563dfbd1bc/src/python/grpcio/_parallel_compile_patch.py", line 58, in _parallel_compile
#           multiprocessing.pool.ThreadPool(BUILD_EXT_COMPILER_JOBS).map(
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/multiprocessing/pool.py", line 367, in map
#           return self._map_async(func, iterable, mapstar, chunksize).get()
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/multiprocessing/pool.py", line 774, in get
#           raise self._value
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#           result = (True, func(*args, **kwds))
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#           return list(map(*args))
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-76iwm6xe/grpcio_8a4265f8188c43858205a7563dfbd1bc/src/python/grpcio/_parallel_compile_patch.py", line 54, in _compile_single_file
#           self._compile(obj, src, ext, cc_args, extra_postargs, pp_opts)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/unixccompiler.py", line 188, in _compile
#           raise CompileError(msg)
#       distutils.errors.CompileError: command '/usr/bin/clang' failed with exit code 1
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-76iwm6xe/grpcio_8a4265f8188c43858205a7563dfbd1bc/setup.py", line 537, in <module>
#           setuptools.setup(
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/__init__.py", line 87, in setup
#           return distutils.core.setup(**attrs)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/wheel/bdist_wheel.py", line 325, in run
#           self.run_command("build")
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/build.py", line 132, in run
#           self.run_command(cmd_name)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/command/build_ext.py", line 84, in run
#           _build_ext.run(self)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/Cython/Distutils/old_build_ext.py", line 186, in run
#           _build_ext.build_ext.run(self)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 346, in run
#           self.build_extensions()
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-76iwm6xe/grpcio_8a4265f8188c43858205a7563dfbd1bc/src/python/grpcio/commands.py", line 284, in build_extensions
#           support.diagnose_build_ext_error(self, error, formatted_exception)
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-76iwm6xe/grpcio_8a4265f8188c43858205a7563dfbd1bc/src/python/grpcio/support.py", line 117, in diagnose_build_ext_error
#           diagnostic(build_ext, error)
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-76iwm6xe/grpcio_8a4265f8188c43858205a7563dfbd1bc/src/python/grpcio/support.py", line 76, in diagnose_compile_error
#           _expect_compile(build_ext.compiler, c_check, message)
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-76iwm6xe/grpcio_8a4265f8188c43858205a7563dfbd1bc/src/python/grpcio/support.py", line 68, in _expect_compile
#           raise commands.CommandError(
#       commands.CommandError: Diagnostics found a compilation environment issue:
#
#       Could not find <Python.h>. This could mean the following:
#         * You're on Ubuntu and haven't run `apt-get install python3-dev`.
#         * You're on RHEL/Fedora and haven't run `yum install python3-devel` or
#           `dnf install python3-devel` (make sure you also have redhat-rpm-config
#           installed)
#         * You're on Mac OS X and the usual Python framework was somehow corrupted
#           (check your environment variables or try re-installing?)
#         * You're on Windows and your Python installation was somehow corrupted
#           (check your environment variables or try re-installing?)
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for grpcio
#   Running setup.py clean for grpcio
# Successfully built fvcore
# Failed to build detectron2 pycocotools grpcio
# ERROR: Could not build wheels for pycocotools, which is required to install pyproject.toml-based projects

# %%
# !pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-req-build-0evvsiug
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-req-build-0evvsiug
#   Resolved https://github.com/facebookresearch/detectron2.git to commit ebb26b5b0d914a9fc196da303e536892165a7113
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (9.4.0)
# Requirement already satisfied: matplotlib in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (3.7.0)
# Collecting pycocotools>=2.0.2
#   Using cached pycocotools-2.0.6.tar.gz (24 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: termcolor>=1.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (2.2.0)
# Collecting yacs>=0.1.8
#   Using cached yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (0.8.10)
# Requirement already satisfied: cloudpickle in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (2.0.0)
# Requirement already satisfied: tqdm>4.29.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (4.64.1)
# Collecting tensorboard
#   Using cached tensorboard-2.12.2-py3-none-any.whl (5.6 MB)
# Collecting fvcore<0.1.6,>=0.1.5
#   Using cached fvcore-0.1.5.post20221221-py3-none-any.whl
# Collecting iopath<0.1.10,>=0.1.7
#   Using cached iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf>=2.1
#   Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Collecting hydra-core>=1.1
#   Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Requirement already satisfied: black in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (22.6.0)
# Requirement already satisfied: packaging in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from detectron2==0.6) (22.0)
# Requirement already satisfied: numpy in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0)
# Collecting antlr4-python3-runtime==4.9.*
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Collecting portalocker
#   Using cached portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (4.25.0)
# Requirement already satisfied: tomli>=1.1.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2==0.6) (0.4.3)
# Requirement already satisfied: click>=8.0.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2==0.6) (8.0.4)
# Requirement already satisfied: platformdirs>=2 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2==0.6) (2.5.2)
# Requirement already satisfied: pathspec>=0.9.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from black->detectron2==0.6) (0.10.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (1.8.1)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.17.3-py2.py3-none-any.whl (178 kB)
# Requirement already satisfied: protobuf>=3.19.6 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (4.22.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (65.6.3)
# Requirement already satisfied: wheel>=0.26 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (0.38.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (2.28.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (0.7.0)
# Collecting absl-py>=0.4
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Collecting grpcio>=1.48.2
#   Using cached grpcio-1.54.0.tar.gz (23.5 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.9.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.2.8)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Building wheels for collected packages: detectron2, pycocotools, grpcio
#   Building wheel for detectron2 (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [444 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-10.9-x86_64-cpython-310
#       creating build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/lightning_train_net.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/convert-torchvision-to-d2.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/benchmark.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/visualize_data.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/plain_train_net.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/visualize_json_results.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/analyze_model.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/lazyconfig_train_net.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       copying tools/train_net.py -> build/lib.macosx-10.9-x86_64-cpython-310/tools
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2
#       copying detectron2/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/checkpoint
#       copying detectron2/checkpoint/catalog.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/checkpoint
#       copying detectron2/checkpoint/c2_model_loading.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/checkpoint
#       copying detectron2/checkpoint/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/checkpoint
#       copying detectron2/checkpoint/detection_checkpoint.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/checkpoint
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/deform_conv.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/shape_spec.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/roi_align.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/roi_align_rotated.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/nms.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/aspp.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/mask_ops.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/wrappers.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/losses.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/blocks.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/batch_norm.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       copying detectron2/layers/rotated_boxes.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/layers
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/instances.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/boxes.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/keypoints.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/masks.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/image_list.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       copying detectron2/structures/rotated_boxes.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/structures
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       copying detectron2/config/config.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       copying detectron2/config/compat.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       copying detectron2/config/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       copying detectron2/config/instantiate.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       copying detectron2/config/defaults.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       copying detectron2/config/lazy.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/config
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects
#       copying detectron2/projects/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/serialize.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/colormap.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/tracing.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/env.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/analysis.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/comm.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/memory.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/video_visualizer.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/registry.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/events.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/collect_env.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/logger.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/file_io.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/develop.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/testing.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       copying detectron2/utils/visualizer.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/utils
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/solver
#       copying detectron2/solver/build.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/solver
#       copying detectron2/solver/lr_scheduler.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/solver
#       copying detectron2/solver/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/solver
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo
#       copying detectron2/model_zoo/model_zoo.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo
#       copying detectron2/model_zoo/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/test_time_augmentation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/poolers.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/matcher.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/box_regression.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/mmdet_wrapper.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/anchor_generator.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/sampling.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       copying detectron2/modeling/postprocessing.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/fast_eval_api.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/panoptic_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/cityscapes_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/coco_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/sem_seg_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/pascal_voc_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/lvis_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/testing.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/evaluator.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       copying detectron2/evaluation/rotated_coco_evaluation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/evaluation
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/bbox_iou_tracker.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/vanilla_hungarian_bbox_iou_tracker.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/hungarian_tracker.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/base_tracker.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/utils.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       copying detectron2/tracking/iou_weighted_hungarian_bbox_iou_tracker.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/tracking
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/c10.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/caffe2_export.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/flatten.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/caffe2_patch.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/caffe2_modeling.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/shared.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/api.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/caffe2_inference.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/torchscript_patch.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       copying detectron2/export/torchscript.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/export
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/catalog.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/build.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/benchmark.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/detection_utils.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/dataset_mapper.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       copying detectron2/data/common.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/engine
#       copying detectron2/engine/hooks.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/engine
#       copying detectron2/engine/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/engine
#       copying detectron2/engine/train_loop.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/engine
#       copying detectron2/engine/launch.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/engine
#       copying detectron2/engine/defaults.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/engine
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/build.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/rcnn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/panoptic_fpn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/dense_detector.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/fcos.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/retinanet.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       copying detectron2/modeling/meta_arch/semantic_seg.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/meta_arch
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/proposal_generator
#       copying detectron2/modeling/proposal_generator/build.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/proposal_generator
#       copying detectron2/modeling/proposal_generator/rpn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/proposal_generator
#       copying detectron2/modeling/proposal_generator/rrpn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/proposal_generator
#       copying detectron2/modeling/proposal_generator/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/proposal_generator
#       copying detectron2/modeling/proposal_generator/proposal_utils.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/proposal_generator
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/mask_head.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/fast_rcnn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/box_head.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/keypoint_head.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/rotated_fast_rcnn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/cascade_rcnn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       copying detectron2/modeling/roi_heads/roi_heads.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/roi_heads
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/build.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/fpn.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/regnet.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/swin.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/backbone.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/vit.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/resnet.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/utils.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       copying detectron2/modeling/backbone/mvit.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/modeling/backbone
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/coco.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/register_coco.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/cityscapes.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/cityscapes_panoptic.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/lvis_v1_categories.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/lvis.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/coco_panoptic.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/builtin.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/lvis_v1_category_image_count.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/pascal_voc.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/lvis_v0_5_categories.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       copying detectron2/data/datasets/builtin_meta.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/datasets
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/transforms
#       copying detectron2/data/transforms/augmentation_impl.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/transforms
#       copying detectron2/data/transforms/augmentation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/transforms
#       copying detectron2/data/transforms/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/transforms
#       copying detectron2/data/transforms/transform.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/transforms
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/samplers
#       copying detectron2/data/samplers/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/samplers
#       copying detectron2/data/samplers/grouped_batch_sampler.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/samplers
#       copying detectron2/data/samplers/distributed_sampler.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/data/samplers
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/point_features.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/mask_head.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/config.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/point_head.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/roi_heads.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/color_augmentation.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       copying projects/PointRend/point_rend/semantic_seg.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/point_rend
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/lr_scheduler.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/config.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/loss.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/resnet.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/build_solver.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       copying projects/DeepLab/deeplab/semantic_seg.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/deeplab
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       copying projects/Panoptic-DeepLab/panoptic_deeplab/config.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       copying projects/Panoptic-DeepLab/panoptic_deeplab/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       copying projects/Panoptic-DeepLab/panoptic_deeplab/dataset_mapper.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       copying projects/Panoptic-DeepLab/panoptic_deeplab/panoptic_seg.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       copying projects/Panoptic-DeepLab/panoptic_deeplab/post_processing.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       copying projects/Panoptic-DeepLab/panoptic_deeplab/target_generator.py -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/projects/panoptic_deeplab
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs
#       copying detectron2/model_zoo/configs/Base-RetinaNet.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs
#       copying detectron2/model_zoo/configs/Base-RCNN-FPN.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs
#       copying detectron2/model_zoo/configs/Base-RCNN-C4.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs
#       copying detectron2/model_zoo/configs/Base-RCNN-DilatedC5.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/scratch_mask_rcnn_R_50_FPN_9x_syncbn.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/mask_rcnn_R_50_FPN_3x_dconv_c3-c5.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/semantic_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/scratch_mask_rcnn_R_50_FPN_3x_gn.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/panoptic_fpn_R_101_dconv_cascade_gn_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/scratch_mask_rcnn_R_50_FPN_9x_gn.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/mask_rcnn_R_50_FPN_3x_gn.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/mask_rcnn_R_50_FPN_1x_dconv_c3-c5.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/cascade_mask_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/cascade_mask_rcnn_X_152_32x8d_FPN_IN5k_gn_dconv.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/mask_rcnn_R_50_FPN_1x_cls_agnostic.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/cascade_mask_rcnn_R_50_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       copying detectron2/model_zoo/configs/Misc/mask_rcnn_R_50_FPN_3x_syncbn.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Misc
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Keypoints
#       copying detectron2/model_zoo/configs/COCO-Keypoints/keypoint_rcnn_X_101_32x8d_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Keypoints
#       copying detectron2/model_zoo/configs/COCO-Keypoints/keypoint_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Keypoints
#       copying detectron2/model_zoo/configs/COCO-Keypoints/keypoint_rcnn_R_50_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Keypoints
#       copying detectron2/model_zoo/configs/COCO-Keypoints/Base-Keypoint-RCNN-FPN.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Keypoints
#       copying detectron2/model_zoo/configs/COCO-Keypoints/keypoint_rcnn_R_101_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Keypoints
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/PascalVOC-Detection
#       copying detectron2/model_zoo/configs/PascalVOC-Detection/faster_rcnn_R_50_FPN.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/PascalVOC-Detection
#       copying detectron2/model_zoo/configs/PascalVOC-Detection/faster_rcnn_R_50_C4.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/PascalVOC-Detection
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Detectron1-Comparisons
#       copying detectron2/model_zoo/configs/Detectron1-Comparisons/mask_rcnn_R_50_FPN_noaug_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Detectron1-Comparisons
#       copying detectron2/model_zoo/configs/Detectron1-Comparisons/keypoint_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Detectron1-Comparisons
#       copying detectron2/model_zoo/configs/Detectron1-Comparisons/faster_rcnn_R_50_FPN_noaug_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/Detectron1-Comparisons
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/rpn_R_50_C4_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/rpn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_101_C4_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/retinanet_R_101_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_101_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_50_DC5_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_50_DC5_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_50_C4_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_50_C4_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/fast_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/retinanet_R_50_FPN_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/faster_rcnn_R_101_DC5_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       copying detectron2/model_zoo/configs/COCO-Detection/retinanet_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-Detection
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-PanopticSegmentation
#       copying detectron2/model_zoo/configs/COCO-PanopticSegmentation/panoptic_fpn_R_101_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-PanopticSegmentation
#       copying detectron2/model_zoo/configs/COCO-PanopticSegmentation/Base-Panoptic-FPN.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-PanopticSegmentation
#       copying detectron2/model_zoo/configs/COCO-PanopticSegmentation/panoptic_fpn_R_50_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-PanopticSegmentation
#       copying detectron2/model_zoo/configs/COCO-PanopticSegmentation/panoptic_fpn_R_50_3x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/COCO-PanopticSegmentation
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv1-InstanceSegmentation
#       copying detectron2/model_zoo/configs/LVISv1-InstanceSegmentation/mask_rcnn_R_101_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv1-InstanceSegmentation
#       copying detectron2/model_zoo/configs/LVISv1-InstanceSegmentation/mask_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv1-InstanceSegmentation
#       copying detectron2/model_zoo/configs/LVISv1-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv1-InstanceSegmentation
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation
#       copying detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation/mask_rcnn_R_101_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation
#       copying detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation/mask_rcnn_R_50_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation
#       copying detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_1x.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/LVISv0.5-InstanceSegmentation
#       creating build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/keypoint_rcnn_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_FPN_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_C4_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/cascade_mask_rcnn_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_C4_GCV_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_C4_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_FPN_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/panoptic_fpn_R_50_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/retinanet_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_DC5_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/retinanet_R_50_FPN_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_FPN_pred_boxes_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/panoptic_fpn_R_50_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/rpn_R_50_FPN_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/semantic_R_50_FPN_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/keypoint_rcnn_R_50_FPN_normalized_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/panoptic_fpn_R_50_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/cascade_mask_rcnn_R_50_FPN_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/fast_rcnn_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/semantic_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/rpn_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/keypoint_rcnn_R_50_FPN_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/keypoint_rcnn_R_50_FPN_training_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_C4_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/semantic_R_50_FPN_instant_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
#       copying detectron2/model_zoo/configs/quick_schedules/mask_rcnn_R_50_FPN_inference_acc_test.yaml -> build/lib.macosx-10.9-x86_64-cpython-310/detectron2/model_zoo/configs/quick_schedules
# ...
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -D_WIN32_WINNT=1536 -DGRPC_XDS_USER_AGENT_NAME_SUFFIX=\"Python\" -DGRPC_XDS_USER_AGENT_VERSION_SUFFIX=\"1.54.0\" -DGPR_BACKWARDS_COMPATIBILITY_MODE=1 -DHAVE_CONFIG_H=1 -DGRPC_ENABLE_FORK_SUPPORT=1 "-DPyMODINIT_FUNC=extern \"C\" __attribute__((visibility (\"default\"))) PyObject*" -DGRPC_POSIX_FORK_ALLOW_PTHREAD_ATFORK=1 -Isrc/python/grpcio -Iinclude -I. -Ithird_party/abseil-cpp -Ithird_party/address_sorting/include -Ithird_party/cares/cares/include -Ithird_party/cares -Ithird_party/cares/cares -Ithird_party/cares/config_darwin -Ithird_party/re2 -Ithird_party/boringssl-with-bazel/src/include -Ithird_party/upb -Isrc/core/ext/upb-generated -Isrc/core/ext/upbdefs-generated -Ithird_party/xxhash -Ithird_party/zlib -I/Users/michielbontenbal/anaconda3/include/python3.10 -c third_party/cares/cares/src/lib/ares_getenv.c -o python_build/temp.macosx-10.10-x86_64-cpython-310/third_party/cares/cares/src/lib/ares_getenv.o -std=c++14 -stdlib=libc++ -fvisibility=hidden -fno-wrapv -fno-exceptions -DHAVE_UNISTD_H -pthread
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -D_WIN32_WINNT=1536 -DGRPC_XDS_USER_AGENT_NAME_SUFFIX=\"Python\" -DGRPC_XDS_USER_AGENT_VERSION_SUFFIX=\"1.54.0\" -DGPR_BACKWARDS_COMPATIBILITY_MODE=1 -DHAVE_CONFIG_H=1 -DGRPC_ENABLE_FORK_SUPPORT=1 "-DPyMODINIT_FUNC=extern \"C\" __attribute__((visibility (\"default\"))) PyObject*" -DGRPC_POSIX_FORK_ALLOW_PTHREAD_ATFORK=1 -Isrc/python/grpcio -Iinclude -I. -Ithird_party/abseil-cpp -Ithird_party/address_sorting/include -Ithird_party/cares/cares/include -Ithird_party/cares -Ithird_party/cares/cares -Ithird_party/cares/config_darwin -Ithird_party/re2 -Ithird_party/boringssl-with-bazel/src/include -Ithird_party/upb -Isrc/core/ext/upb-generated -Isrc/core/ext/upbdefs-generated -Ithird_party/xxhash -Ithird_party/zlib -I/Users/michielbontenbal/anaconda3/include/python3.10 -c third_party/re2/re2/nfa.cc -o python_build/temp.macosx-10.10-x86_64-cpython-310/third_party/re2/re2/nfa.o -std=c++14 -stdlib=libc++ -fvisibility=hidden -fno-wrapv -fno-exceptions -DHAVE_UNISTD_H -pthread
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -D_WIN32_WINNT=1536 -DGRPC_XDS_USER_AGENT_NAME_SUFFIX=\"Python\" -DGRPC_XDS_USER_AGENT_VERSION_SUFFIX=\"1.54.0\" -DGPR_BACKWARDS_COMPATIBILITY_MODE=1 -DHAVE_CONFIG_H=1 -DGRPC_ENABLE_FORK_SUPPORT=1 "-DPyMODINIT_FUNC=extern \"C\" __attribute__((visibility (\"default\"))) PyObject*" -DGRPC_POSIX_FORK_ALLOW_PTHREAD_ATFORK=1 -Isrc/python/grpcio -Iinclude -I. -Ithird_party/abseil-cpp -Ithird_party/address_sorting/include -Ithird_party/cares/cares/include -Ithird_party/cares -Ithird_party/cares/cares -Ithird_party/cares/config_darwin -Ithird_party/re2 -Ithird_party/boringssl-with-bazel/src/include -Ithird_party/upb -Isrc/core/ext/upb-generated -Isrc/core/ext/upbdefs-generated -Ithird_party/xxhash -Ithird_party/zlib -I/Users/michielbontenbal/anaconda3/include/python3.10 -c third_party/zlib/gzclose.c -o python_build/temp.macosx-10.10-x86_64-cpython-310/third_party/zlib/gzclose.o -std=c++14 -stdlib=libc++ -fvisibility=hidden -fno-wrapv -fno-exceptions -DHAVE_UNISTD_H -pthread
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       creating None
#       creating None/var
#       creating None/var/folders
#       creating None/var/folders/cj
#       creating None/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn
#       creating None/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T
#       creating None/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmpgcod0efa
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -fPIC -O2 -isystem /Users/michielbontenbal/anaconda3/include -I/Users/michielbontenbal/anaconda3/include/python3.10 -c /var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmpgcod0efa/a.c -o None/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/tmpgcod0efa/a.o
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#
#       Could not find <Python.h>. This could mean the following:
#         * You're on Ubuntu and haven't run `apt-get install python3-dev`.
#         * You're on RHEL/Fedora and haven't run `yum install python3-devel` or
#           `dnf install python3-devel` (make sure you also have redhat-rpm-config
#           installed)
#         * You're on Mac OS X and the usual Python framework was somehow corrupted
#           (check your environment variables or try re-installing?)
#         * You're on Windows and your Python installation was somehow corrupted
#           (check your environment variables or try re-installing?)
#       Traceback (most recent call last):
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/unixccompiler.py", line 186, in _compile
#           self.spawn(compiler_so + cc_args + [src, '-o', obj] + extra_postargs)
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-3u2s8xun/grpcio_fa5b4c99f70e4a73a53593e13b00c1d7/src/python/grpcio/_spawn_patch.py", line 54, in _commandfile_spawn
#           _classic_spawn(self, command)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/ccompiler.py", line 1007, in spawn
#           spawn(cmd, dry_run=self.dry_run, **kwargs)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/spawn.py", line 70, in spawn
#           raise DistutilsExecError(
#       distutils.errors.DistutilsExecError: command '/usr/bin/clang' failed with exit code 1
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-3u2s8xun/grpcio_fa5b4c99f70e4a73a53593e13b00c1d7/src/python/grpcio/commands.py", line 281, in build_extensions
#           build_ext.build_ext.build_extensions(self)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/Cython/Distutils/old_build_ext.py", line 195, in build_extensions
#           _build_ext.build_ext.build_extensions(self)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 468, in build_extensions
#           self._build_extensions_serial()
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 494, in _build_extensions_serial
#           self.build_extension(ext)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/command/build_ext.py", line 246, in build_extension
#           _build_ext.build_extension(self, ext)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 549, in build_extension
#           objects = self.compiler.compile(
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-3u2s8xun/grpcio_fa5b4c99f70e4a73a53593e13b00c1d7/src/python/grpcio/_parallel_compile_patch.py", line 58, in _parallel_compile
#           multiprocessing.pool.ThreadPool(BUILD_EXT_COMPILER_JOBS).map(
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/multiprocessing/pool.py", line 367, in map
#           return self._map_async(func, iterable, mapstar, chunksize).get()
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/multiprocessing/pool.py", line 774, in get
#           raise self._value
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#           result = (True, func(*args, **kwds))
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#           return list(map(*args))
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-3u2s8xun/grpcio_fa5b4c99f70e4a73a53593e13b00c1d7/src/python/grpcio/_parallel_compile_patch.py", line 54, in _compile_single_file
#           self._compile(obj, src, ext, cc_args, extra_postargs, pp_opts)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/unixccompiler.py", line 188, in _compile
#           raise CompileError(msg)
#       distutils.errors.CompileError: command '/usr/bin/clang' failed with exit code 1
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-3u2s8xun/grpcio_fa5b4c99f70e4a73a53593e13b00c1d7/setup.py", line 537, in <module>
#           setuptools.setup(
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/__init__.py", line 87, in setup
#           return distutils.core.setup(**attrs)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/wheel/bdist_wheel.py", line 325, in run
#           self.run_command("build")
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/build.py", line 132, in run
#           self.run_command(cmd_name)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/command/build_ext.py", line 84, in run
#           _build_ext.run(self)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/Cython/Distutils/old_build_ext.py", line 186, in run
#           _build_ext.build_ext.run(self)
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 346, in run
#           self.build_extensions()
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-3u2s8xun/grpcio_fa5b4c99f70e4a73a53593e13b00c1d7/src/python/grpcio/commands.py", line 284, in build_extensions
#           support.diagnose_build_ext_error(self, error, formatted_exception)
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-3u2s8xun/grpcio_fa5b4c99f70e4a73a53593e13b00c1d7/src/python/grpcio/support.py", line 117, in diagnose_build_ext_error
#           diagnostic(build_ext, error)
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-3u2s8xun/grpcio_fa5b4c99f70e4a73a53593e13b00c1d7/src/python/grpcio/support.py", line 76, in diagnose_compile_error
#           _expect_compile(build_ext.compiler, c_check, message)
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-3u2s8xun/grpcio_fa5b4c99f70e4a73a53593e13b00c1d7/src/python/grpcio/support.py", line 68, in _expect_compile
#           raise commands.CommandError(
#       commands.CommandError: Diagnostics found a compilation environment issue:
#
#       Could not find <Python.h>. This could mean the following:
#         * You're on Ubuntu and haven't run `apt-get install python3-dev`.
#         * You're on RHEL/Fedora and haven't run `yum install python3-devel` or
#           `dnf install python3-devel` (make sure you also have redhat-rpm-config
#           installed)
#         * You're on Mac OS X and the usual Python framework was somehow corrupted
#           (check your environment variables or try re-installing?)
#         * You're on Windows and your Python installation was somehow corrupted
#           (check your environment variables or try re-installing?)
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for grpcio
#   Running setup.py clean for grpcio
# Failed to build detectron2 pycocotools grpcio
# ERROR: Could not build wheels for pycocotools, which is required to install pyproject.toml-based projects

# %%
# !pip install pdfminer
# Out:
# Collecting pdfminer
#   Downloading pdfminer-20191125.tar.gz (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 10.9 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting pycryptodome
#   Downloading pycryptodome-3.17-cp35-abi3-macosx_10_9_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 8.7 MB/s eta 0:00:00:00:0100:01
# Building wheels for collected packages: pdfminer
#   Building wheel for pdfminer (setup.py) ... done
#   Created wheel for pdfminer: filename=pdfminer-20191125-py3-none-any.whl size=6140068 sha256=693ae7aed86eb995501f606fdd2708fe3ee9cb04237ff614c5023ce332bd88c2
#   Stored in directory: /Users/michielbontenbal/Library/Caches/pip/wheels/b6/02/c9/adcd788c3ed26716f0be0d92c19daeec173ab822641de69fc0
# Successfully built pdfminer
# Installing collected packages: pycryptodome, pdfminer
# Successfully installed pdfminer-20191125 pycryptodome-3.17

# %%
# !pip install unstructured
# Out:
# Collecting unstructured
#   Using cached unstructured-0.5.13-py3-none-any.whl (1.3 MB)
# Collecting python-magic
#   Using cached python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: markdown in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from unstructured) (3.4.1)
# Requirement already satisfied: certifi>=2022.12.07 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from unstructured) (2022.12.7)
# Collecting msg-parser
#   Using cached msg_parser-1.2.0-py2.py3-none-any.whl (101 kB)
# Collecting argilla
#   Using cached argilla-1.6.0-py3-none-any.whl (2.2 MB)
# Collecting pypandoc
#   Using cached pypandoc-1.11-py3-none-any.whl (20 kB)
# Requirement already satisfied: nltk in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from unstructured) (3.7)
# Requirement already satisfied: pandas in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from unstructured) (1.5.3)
# Collecting python-docx
#   Using cached python_docx-0.8.11-py3-none-any.whl
# Collecting python-pptx
#   Using cached python_pptx-0.6.21-py3-none-any.whl
# Requirement already satisfied: requests in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from unstructured) (2.28.1)
# Requirement already satisfied: lxml in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from unstructured) (4.9.1)
# Requirement already satisfied: openpyxl in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from unstructured) (3.0.10)
# Requirement already satisfied: pillow in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from unstructured) (9.4.0)
# Collecting numpy<1.24.0
#   Using cached numpy-1.23.5-cp310-cp310-macosx_10_9_x86_64.whl (18.1 MB)
# Collecting deprecated~=1.2.0
#   Using cached Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: tqdm>=4.27.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from argilla->unstructured) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from argilla->unstructured) (22.0)
# Requirement already satisfied: backoff in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from argilla->unstructured) (2.2.1)
# Collecting httpx<0.24,>=0.15
#   Using cached httpx-0.23.3-py3-none-any.whl (71 kB)
# Requirement already satisfied: pydantic>=1.7.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from argilla->unstructured) (1.10.7)
# Collecting rich<=13.0.1
#   Using cached rich-13.0.1-py3-none-any.whl (238 kB)
# Requirement already satisfied: wrapt<1.15,>=1.13 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from argilla->unstructured) (1.14.1)
# Requirement already satisfied: monotonic in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from argilla->unstructured) (1.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from pandas->unstructured) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from pandas->unstructured) (2022.7)
# Collecting olefile>=0.46
#   Using cached olefile-0.46-py2.py3-none-any.whl
# Requirement already satisfied: regex>=2021.8.3 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from nltk->unstructured) (2022.7.9)
# Requirement already satisfied: joblib in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from nltk->unstructured) (1.1.1)
# Requirement already satisfied: click in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from nltk->unstructured) (8.0.4)
# Requirement already satisfied: et_xmlfile in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from openpyxl->unstructured) (1.1.0)
# Collecting XlsxWriter>=0.5.7
#   Using cached XlsxWriter-3.1.0-py3-none-any.whl (152 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests->unstructured) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests->unstructured) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests->unstructured) (3.4)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Using cached rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: sniffio in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from httpx<0.24,>=0.15->argilla->unstructured) (1.2.0)
# Collecting httpcore<0.17.0,>=0.15.0
#   Using cached httpcore-0.16.3-py3-none-any.whl (69 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from pydantic>=1.7.1->argilla->unstructured) (4.4.0)
# Requirement already satisfied: six>=1.5 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->unstructured) (1.16.0)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from rich<=13.0.1->argilla->unstructured) (2.11.2)
# Collecting commonmark<0.10.0,>=0.9.0
#   Using cached commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from httpcore<0.17.0,>=0.15.0->httpx<0.24,>=0.15->argilla->unstructured) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from httpcore<0.17.0,>=0.15.0->httpx<0.24,>=0.15->argilla->unstructured) (3.5.0)
# Installing collected packages: rfc3986, commonmark, XlsxWriter, rich, python-magic, python-docx, pypandoc, olefile, numpy, deprecated, python-pptx, msg-parser, httpcore, httpx, argilla, unstructured
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.2
#     Uninstalling numpy-1.24.2:
#       Successfully uninstalled numpy-1.24.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# Successfully installed XlsxWriter-3.1.0 argilla-1.6.0 commonmark-0.9.1 deprecated-1.2.13 httpcore-0.16.3 httpx-0.23.3 msg-parser-1.2.0 numpy-1.23.5 olefile-0.46 pypandoc-1.11 python-docx-0.8.11 python-magic-0.4.27 python-pptx-0.6.21 rfc3986-1.5.0 rich-13.0.1 unstructured-0.5.13

# %%
import os
from langchain.document_loaders import UnstructuredPDFLoader
from langchain.indexes import VectorstoreIndexCreator
#from detectron2.config import get_cfg

# %%
import config
import os
os.environ['OPENAI_API_KEY'] = config.openai_key

# %%
print(os.environ['OPENAI_API_KEY'])
# Out:
# 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

# %%
#cfg = get_cfg()    
#cfg.MODEL.DEVICE = 'cpu'


pdf_folder_name = 'PDF'

def create_pdf_loaders(pdf_folder_name):
    loaders = []
    for i in os.listdir(pdf_folder_name):
        file_path = os.path.join(pdf_folder_name, i)
        loader = UnstructuredPDFLoader(file_path)
        loaders.append(loader)
    return loaders

loaders = create_pdf_loaders(pdf_folder_name)
print(loaders)
# Out:
# [<langchain.document_loaders.pdf.UnstructuredPDFLoader object at 0x7fe61d61d000>, <langchain.document_loaders.pdf.UnstructuredPDFLoader object at 0x7fe61d61d870>, <langchain.document_loaders.pdf.UnstructuredPDFLoader object at 0x7fe61d3116f0>]

# %%
loaders
# Out:
# [<langchain.document_loaders.pdf.UnstructuredPDFLoader at 0x7fe61d317e80>,
#  <langchain.document_loaders.pdf.UnstructuredPDFLoader at 0x7fe61d61f640>,
#  <langchain.document_loaders.pdf.UnstructuredPDFLoader at 0x7fe61d61c970>]

# %%
index = VectorstoreIndexCreator().from_loaders(loaders)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/unstructured/partition/pdf.py:158, in _partition_pdf_or_image_local(filename, file, template, is_image, include_page_breaks)
#     157 try:
# --> 158     from unstructured_inference.inference.layout import (
#     159         process_data_with_model,
#     160         process_file_with_model,
#     161     )
#     162 except ModuleNotFoundError as e:
#
# File ~/anaconda3/lib/python3.10/site-packages/unstructured_inference/inference/layout.py:16
#      15 import unstructured_inference.models.tesseract as tesseract
# ---> 16 import unstructured_inference.models.tables as tables
#      17 from unstructured_inference.models.base import get_model
#
# File ~/anaconda3/lib/python3.10/site-packages/unstructured_inference/models/tables.py:19
#      18 from transformers import TableTransformerForObjectDetection
# ---> 19 from transformers import DetrImageProcessor
#      20 from PIL import Image
#
# ImportError: cannot import name 'DetrImageProcessor' from 'transformers' (/Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/transformers/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 index = VectorstoreIndexCreator().from_loaders(loaders)
#
# File ~/anaconda3/lib/python3.10/site-packages/langchain/indexes/vectorstore.py:69, in VectorstoreIndexCreator.from_loaders(self, loaders)
#      67 docs = []
#      68 for loader in loaders:
# ---> 69     docs.extend(loader.load())
#      70 sub_docs = self.text_splitter.split_documents(docs)
#      71 vectorstore = self.vectorstore_cls.from_documents(
#      72     sub_docs, self.embedding, **self.vectorstore_kwargs
#      73 )
#
# File ~/anaconda3/lib/python3.10/site-packages/langchain/document_loaders/unstructured.py:61, in UnstructuredBaseLoader.load(self)
#      59 def load(self) -> List[Document]:
#      60     """Load file."""
# ---> 61     elements = self._get_elements()
#      62     if self.mode == "elements":
#      63         docs: List[Document] = list()
#
# File ~/anaconda3/lib/python3.10/site-packages/langchain/document_loaders/pdf.py:21, in UnstructuredPDFLoader._get_elements(self)
#      18 def _get_elements(self) -> List:
#      19     from unstructured.partition.pdf import partition_pdf
# ---> 21     return partition_pdf(filename=self.file_path, **self.unstructured_kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/unstructured/partition/pdf.py:50, in partition_pdf(filename, file, url, template, token, include_page_breaks, strategy, encoding)
#      27 """Parses a pdf document into a list of interpreted elements.
#      28 Parameters
#      29 ----------
#    (...)
#      47     The encoding method used to decode the text input. If None, utf-8 will be used.
#      48 """
#      49 exactly_one(filename=filename, file=file)
# ---> 50 return partition_pdf_or_image(
#      51     filename=filename,
#      52     file=file,
#      53     url=url,
#      54     template=template,
#      55     token=token,
#      56     include_page_breaks=include_page_breaks,
#      57     strategy=strategy,
#      58     encoding=encoding,
#      59 )
#
# File ~/anaconda3/lib/python3.10/site-packages/unstructured/partition/pdf.py:100, in partition_pdf_or_image(filename, file, url, template, token, is_image, include_page_breaks, strategy, encoding)
#      98     with warnings.catch_warnings():
#      99         warnings.simplefilter("ignore")
# --> 100         layout_elements = _partition_pdf_or_image_local(
#     101             filename=filename,
#     102             file=file,
#     103             template=out_template,
#     104             is_image=is_image,
#     105             include_page_breaks=True,
#     106         )
#     108 elif strategy == "fast" or fallback_to_fast:
#     109     if strategy == "hi_res":
#
# File ~/anaconda3/lib/python3.10/site-packages/unstructured/partition/pdf.py:170, in _partition_pdf_or_image_local(filename, file, template, is_image, include_page_breaks)
#     163     raise Exception(
#     164         "unstructured_inference module not found... try running pip install "
#     165         "unstructured[local-inference] if you installed the unstructured library as a package. "
#     166         "If you cloned the unstructured repository, try running make install-local-inference "
#     167         "from the root directory of the repository.",
#     168     ) from e
#     169 except ImportError as e:
# --> 170     raise Exception(
#     171         "There was a problem importing unstructured_inference module - it may not be installed "
#     172         "correctly... try running pip install unstructured[local-inference] if you installed "
#     173         "the unstructured library as a package. If you cloned the unstructured repository, try "
#     174         "running make install-local-inference from the root directory of the repository.",
#     175     ) from e
#     177 layout = (
#     178     process_file_with_model(filename, template, is_image=is_image)
#     179     if file is None
#     180     else process_data_with_model(file, template, is_image=is_image)
#     181 )
#     183 return document_to_element_list(layout, include_page_breaks=include_page_breaks)
#
# Exception: There was a problem importing unstructured_inference module - it may not be installed correctly... try running pip install unstructured[local-inference] if you installed the unstructured library as a package. If you cloned the unstructured repository, try running make install-local-inference from the root directory of the repository.

# %%
query = "What is the name of the book I just fed you?"
index.query(query)

# %%
query = "Tell me one of the things every programmer should know."
index.query(query)

# %%
query = "Who is the author of the book?"
index.query(query)

# %%
query = "What did Chuck Allison say in the book?"
index.query(query)
